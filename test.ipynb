# %%
# %load_ext autoreload
# %autoreload 2

import geocrime_stl.data_cleaner as dc

# %%
import geocrime_stl.data_cleaner as dc
import pandas as pd

# One line to get the data
df = dc.fetch_stl_crime_data("https://slmpd.org/wp-content/uploads/2026/05/April2026.csv")

# One line to clean it
clean_df = dc.clean_crime_dataframe(df)

# One line to map it
gdf = dc.create_geodataframe(clean_df, boundary_path='data/stl_boundary.geojson')

# Now you can just play with the data!
gdf.plot()
